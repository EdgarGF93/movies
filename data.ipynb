# %%
from main import IMDB
import pandas as pd

# %%
movies = IMDB()
# Out:
# c:\Users\edgar1993a\Work Folders\Documents\GitHub\movies\main.py:17: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(

# %%
movies.n_movies()
# Out:
# The dataset contains 10100795 movies: 10.100795 millions.

# %%
data = movies.data

# %%
len(data.columns)
# Out:
# 9

# %%
data
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10100790  tt9916848  tvEpisode              Episode #3.17
# 10100791  tt9916850  tvEpisode              Episode #3.19
# 10100792  tt9916852  tvEpisode              Episode #3.20
# 10100793  tt9916856      short                   The Wind
# 10100794  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
data.iloc[0].size
# Out:
# 9

# %%
data.shape
# Out:
# (10100795, 9)

# %%
s0 = data.iloc[0]

# %%
for k,v in s0.items():
    print(f"{k} is {v}")
# Out:
# tconst is tt0000001
# titleType is short
# primaryTitle is Carmencita
# originalTitle is Carmencita
# isAdult is 0
# startYear is 1894
# endYear is \N
# runtimeMinutes is 1
# genres is Documentary,Short

# %%
type(s0.keys())
# Out:
# pandas.core.indexes.base.Index

# %%
s0.values.size
# Out:
# 9

# %%
data.iloc[int(1000)]['startYear']
# Out:
# '1909'

# %%
data.iloc[int(1000)]['startYear'] = int(1909)

# %%
for row in range(len(data)):
    try:
        startyear = data.iloc[int(row)]['startYear']
    except:
        print(row)
    try:
        data.iloc[int(1000)]['startYear'] = int(startyear)
    except:
        print(row)
# Out:
# 619
# 14182
# 20796
# 21423
# 59809
# 65753
# 79353
# 81513
# 83799
# 85129
# 85240
# 87080
# 90922
# 90968
# 91851
# 92315
# 92540
# 93393
# 95643
# 96629
# 97846
# 99855
# 99856
# 99857
# 99884
# 100303
# 102292
# 102362
# 103002
# 103308
# 103372
# 109077
# 111094
# 111148
# 115762
# 117950
# 117968
# 118022
# 118083
# 118088
# 118163
# 118173
# 118174
# 118191
# 118200
# 118208
# 118234
# 118256
# 118324
# 118387
# 118410
# 118546
# 118585
# 118602
# 118626
# 118643
# 118668
# 118670
# 118702
# 118729
# 118741
# 118768
# 118776
# 119839
# 119864
# 119979
# 120476
# 122346
# 122421
# 122471
# 122996
# 123680
# 123879
# 123951
# 125924
# 125934
# 127605
# 127653
# 128128
# 128307
# 128788
# 129169
# 129934
# 130135
# 130205
# 130408
# 130419
# 131119
# 131461
# 131710
# 131776
# 132100
# 132140
# 132917
# 133745
# 133824
# 134216
# 135767
# 135842
# 135843
# 135844
# 136032
# 137055
# 137138
# 137195
# 137308
# 137894
# 138296
# 138361
# 138380
# 138767
# 139185
# 139338
# 139370
# ...

# %%
startyear = data.iloc[int(0)]['startYear']

# %%
int(startyear)
# Out:
# 1894

# %%
len(data)
# Out:
# 10100795

# %%
data.loc[data['startYear'] >= 2000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.loc[data['startYear'] >= 2000]
#
# File c:\ProgramData\Anaconda3\envs\edgar\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\ProgramData\Anaconda3\envs\edgar\lib\site-packages\pandas\core\arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File c:\ProgramData\Anaconda3\envs\edgar\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
